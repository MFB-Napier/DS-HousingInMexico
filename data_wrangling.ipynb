# %% [markdown]
# <a href="https://colab.research.google.com/github/MFB-Napier/DS-HousingInMexico/blob/master/data_wrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Preparing Mexico Data**

# %%
import pandas as pd

# %% [markdown]
# Read files in a separate DataFrame

# %%
df1=pd.read_csv("/content/mexico-city-real-estate-1.csv")
df1.shape
# Out:
# (4628, 16)

# %%
df1.info
# Out:
# <bound method DataFrame.info of      operation property_type                          place_with_parent_names  \
# 0         sell     apartment         |Miguel Hidalgo|Distrito Federal|México|
# 1         sell         house             |Iztapalapa|Distrito Federal|México|
# 2         sell     apartment                |Tlalpan|Distrito Federal|México|
# 3         sell     apartment         |Miguel Hidalgo|Distrito Federal|México|
# 4         sell     apartment              |Benito Juárez|Quintana Roo|México|
# ...        ...           ...                                              ...
# 4623      sell     apartment              |Benito Juárez|Quintana Roo|México|
# 4624      sell     apartment                |Tlalpan|Distrito Federal|México|
# 4625      sell         house                |Solidaridad|Quintana Roo|México|
# 4626      sell     apartment             |Cuauhtémoc|Distrito Federal|México|
# 4627      sell     apartment  |Cuajimalpa de Morelos|Distrito Federal|México|
#
# ...

# %%
#dropping rows nan
df1.dropna(inplace=True)
df1.info
# Out:
# <bound method DataFrame.info of Empty DataFrame
# Columns: [operation, property_type, place_with_parent_names, lat-lon, price, currency, price_aprox_local_currency, price_aprox_usd, surface_total_in_m2, surface_covered_in_m2, price_usd_per_m2, price_per_m2, floor, rooms, expenses, properati_url]
# Index: []>

# %%
df1.head()
# Out:
#   operation property_type                   place_with_parent_names  \
# 0      sell     apartment  |Miguel Hidalgo|Distrito Federal|México|
# 1      sell         house      |Iztapalapa|Distrito Federal|México|
# 2      sell     apartment         |Tlalpan|Distrito Federal|México|
# 3      sell     apartment  |Miguel Hidalgo|Distrito Federal|México|
# 4      sell     apartment       |Benito Juárez|Quintana Roo|México|
#
#                   lat-lon      price currency  price_aprox_local_currency  \
# 0   23.634501,-102.552788  5500000.0      MXN                  5450245.50
# 1     19.31033,-99.068557  1512000.0      MXN                  1498321.97
# 2    19.279771,-99.234597   926667.0      MXN                   918284.00
# 3   23.634501,-102.552788  6410000.0      MXN                  6352013.39
# 4  21.1902642,-86.8198375   875000.0      USD                 16457437.50
#
#    price_aprox_usd  surface_total_in_m2  surface_covered_in_m2  \
# ...

# %%
df2=pd.read_csv("/content/mexico-city-real-estate-2.csv")
df2.shape
# Out:
# (4628, 16)

# %%
#dropping rows nan
df2.dropna(inplace=True)

# %%
df2.head()
# Out:
#   operation property_type                      place_with_parent_names  \
# 0      sell     apartment  |Gustavo A. Madero|Distrito Federal|México|
# 1      sell     apartment  |Gustavo A. Madero|Distrito Federal|México|
# 2      sell     apartment     |Álvaro Obregón|Distrito Federal|México|
# 3      sell     apartment          |Benito Juárez|Quintana Roo|México|
# 4      sell     apartment      |Benito Juárez|Distrito Federal|México|
#
#                         lat-lon      price currency  \
# 0          19.516777,-99.160149  1200000.0      MXN
# 1          19.466724,-99.131614   480000.0      MXN
# 2           19.33228,-99.243934  4559261.0      MXN
# 3  21.1105772788,-86.8537859927  3808088.0      MXN
# 4            19.39365,-99.14769  1730000.0      MXN
#
#    price_aprox_local_currency  price_aprox_usd  surface_total_in_m2  \
# 0                  1189144.46         63223.78                 88.0
# 1                   475657.74         25289.51                  NaN
# ...

# %%
df3=pd.read_csv("/content/mexico-city-real-estate-3.csv")
df3.shape
# Out:
# (4628, 16)

# %%
#dropping rows nan
df3.dropna(inplace=True)

# %%
df3.head()
# Out:
#   operation property_type                      place_with_parent_names  \
# 0      sell     apartment  |Gustavo A. Madero|Distrito Federal|México|
# 1      sell         house          |Benito Juárez|Quintana Roo|México|
# 2      sell         store  |Gustavo A. Madero|Distrito Federal|México|
# 3      sell         house          |Benito Juárez|Quintana Roo|México|
# 4      sell     apartment         |Iztapalapa|Distrito Federal|México|
#
#                        lat-lon      price currency  \
# 0       19.5010872,-99.1230477  2715592.0      MXN
# 1        21.161908,-86.8515279  5050000.0      MXN
# 2                          NaN  9500000.0      MXN
# 3          21.141616,-86.86109   810000.0      MXN
# 4  19.3603443968,-99.089448452   500000.0      MXN
#
#    price_aprox_local_currency  price_aprox_usd  surface_total_in_m2  \
# 0                  2691025.94        143074.99                  0.0
# 1                  5005502.90        266129.83                400.0
# ...

# %%
df4=pd.read_csv("/content/mexico-city-real-estate-4.csv")
df4.shape
# Out:
# (4628, 16)

# %%
#dropping rows nan
df4.dropna(inplace=True)

# %%
df4.shape
# Out:
# (4628, 16)

# %%
df4.head()
# Out:
#   operation property_type                  place_with_parent_names  \
# 0      sell         house        |Solidaridad|Quintana Roo|México|
# 1      sell         house       |Coyoacán|Distrito Federal|México|
# 2      sell     apartment  |Benito Juárez|Distrito Federal|México|
# 3      sell     apartment      |Iztacalco|Distrito Federal|México|
# 4      sell         house               |Tabasco|Zacatecas|México|
#
#                  lat-lon      price currency  price_aprox_local_currency  \
# 0   20.503029,-87.222649   850000.0      USD                 15987225.00
# 1   19.342077,-99.127866  6310000.0      MXN                  6252917.98
# 2   19.389011,-99.180415  1000000.0      MXN                   990953.65
# 3  23.634501,-102.552788   922096.0      MXN                   913754.35
# 4  23.634501,-102.552788  4000000.0      MXN                  3963814.82
#
#    price_aprox_usd  surface_total_in_m2  surface_covered_in_m2  \
# ...

# %%
df5=pd.read_csv("/content/mexico-city-real-estate-5.csv")
df5.shape
# Out:
# (4628, 16)

# %%
#dropping rows nan
df5.dropna(inplace=True)

# %%
df5.head()
# Out:
#   operation property_type                  place_with_parent_names  \
# 0      sell         house        |Tlalpan|Distrito Federal|México|
# 1      sell     apartment  |Benito Juárez|Distrito Federal|México|
# 2      sell     apartment  |Benito Juárez|Distrito Federal|México|
# 3      sell     apartment        |Tlalpan|Distrito Federal|México|
# 4      sell     apartment     |Iztapalapa|Distrito Federal|México|
#
#                   lat-lon      price currency  price_aprox_local_currency  \
# 0  19.2881277,-99.1383849  4890000.0      MXN                  4845763.63
# 1     19.36269,-99.150565  1570000.0      MXN                  1556166.19
# 2     19.39912,-99.141464  2700000.0      MXN                  2675574.95
# 3    19.291345,-99.124312  1370000.0      MXN                  1357928.55
# 4    19.354987,-99.061709   840400.0      MXN                   832797.49
#
#    price_aprox_usd  surface_total_in_m2  surface_covered_in_m2  \
# ...

# %%
#concant dataframes
df=pd.concat([df1,df2,df3,df4,df5])

# %%
df.shape
# Out:
# (23140, 16)

# %%
df.head()
# Out:
#   operation property_type                   place_with_parent_names  \
# 0      sell     apartment  |Miguel Hidalgo|Distrito Federal|México|
# 1      sell         house      |Iztapalapa|Distrito Federal|México|
# 2      sell     apartment         |Tlalpan|Distrito Federal|México|
# 3      sell     apartment  |Miguel Hidalgo|Distrito Federal|México|
# 4      sell     apartment       |Benito Juárez|Quintana Roo|México|
#
#                   lat-lon      price currency  price_aprox_local_currency  \
# 0   23.634501,-102.552788  5500000.0      MXN                  5450245.50
# 1     19.31033,-99.068557  1512000.0      MXN                  1498321.97
# 2    19.279771,-99.234597   926667.0      MXN                   918284.00
# 3   23.634501,-102.552788  6410000.0      MXN                  6352013.39
# 4  21.1902642,-86.8198375   875000.0      USD                 16457437.50
#
#    price_aprox_usd  surface_total_in_m2  surface_covered_in_m2  \
# ...

# %%
df.to_csv("/content/mexico-city-real-estate.csv", index=False)
